# %% [markdown]
# # My first notebook

# %% [markdown]
# SHortcuts:
# m=markdown
# y=code
# dd=delete
# a=new cell above
# b=new cell below

# %% [markdown]
# In this notebook I will learn about the basic types of variables in python. They are:
# - Strings
# - Integers
# - Floats
#
# _lets go_

# %% [markdown]
# ## strings

# %% [markdown]
# A string is a line of text og numbers.
# You define them in Python with quotation marks like this:

# %%
fruit = "grapes"
fruit
# Out:
# 'grapes'

# %% [markdown]
# strings and integers/floats cannot be combined, even if the string has numbers. Pyhon views strings with numbers as the character number, not the value.
# Can be fixed by changing it to a integer/float variable

# %%
Fruit = "2"
Fruit = int(Fruit)
Fruit
# Out:
# 2

# %% [markdown]
# This only works if the string is a number, not when it is letters

# %% [markdown]
# Comments are something you can write in your code, that Python will ignore.
# You write it like this: # I here attempt to turn fruit into numbers (so you make a hashtag, space and then write the comment)
#
# This is usefull to write down the steps you are doing, or it can lock down pieces/sections of the code. For trying something

# %% [markdown]
# While it is impossible to add strings and numbers, it is possible to and strings to strings

# %%
fruit1 = "grapes"
fruit2 = "bananas"
fruit1 + fruit2
# Out:
# 'grapesbananas'

# %%
dir(fruit1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %% [markdown]
# ## integers

# %% [markdown]
# An integer is a whole number

# %%
7 + 3
# Out:
# 10

# %% [markdown]
# numbers can also be assigned to variables. Variables can be called anything, but best to call them something that makes sense for the work. You cannot use integers to name variables.

# %%
Chips = 2
Cookies = 3

# %%
Chips
# Out:
# 2

# %%
Chips + Cookies
# Out:
# 5

# %%
Snacks = Chips + Cookies

# %%
Snacks
# Out:
# 5

# %%
type(Snacks)
# Out:
# int

# %%
print(Snacks)
# Out:
# 5

# %%
Snacks
# Out:
# 5

# %%
# everything in python is an object, and objects have different propterties
# you can find out which properties an objet have by typing: dir()
dir(Snacks)

# the long text below contains the properties og Snacks. it is everything you can do with the object
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
fruit1.upper()
# Out:
# 'GRAPES'

# %%
fruit1.replace('a','@')
# you can manipulate strings this way
# Out:
# 'gr@pes'

# %% [markdown]
# ## Floats

# %% [markdown]
# Numbers that are not whole (decimal numbers). Be aware that python uses point instead of comma to indiate decimals.

# %%
Cookies = 3.2

# %%
Cookies
# Out:
# 3.2

# %% [markdown]
# The variable "Cookies" have been overridden since we made the integer, it is now a float. Python will NOT let you know when you are overriding a variable, which can be a bit of a problem - as it will change your code. SOlution is to go back to the top and run everything, so things are up to date. Lowercase and uppercase letter differnces make different variables

# %% [markdown]
# ## Othercomments

# %% [markdown]
# Python views the and The as completely different. This can create problems if not careful
